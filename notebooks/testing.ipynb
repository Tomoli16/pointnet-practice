# %%
import sys
sys.path.append("..")
from my_pointnet import SimplePointNet
import torch

B, N = 8, 1024  # 8 Punktwolken, 1024 Punkte pro Wolke
points = torch.rand(B, N, 3)

# %%
model = SimplePointNet()
out = model(points)
print(out.shape)  # Ausgabe der Form des Ausgabewerts
# Out:
# torch.Size([8, 40])
# tensor([-3.6233e-02, -3.2712e-02, -5.5764e-02, -2.0175e-02, -1.3713e-02,
#         -4.3024e-02, -2.5935e-02, -2.2872e-02,  5.6079e-02,  4.4969e-02,
#         -2.0041e-02, -3.5433e-02, -8.6246e-02,  6.3290e-02, -5.7490e-05,
#         -4.7108e-02,  2.8905e-02,  8.5364e-03, -3.5747e-02, -1.8793e-02,
#          6.2414e-02,  4.7278e-02,  1.0883e-02, -6.7849e-03,  3.2024e-02,
#          4.4676e-02,  1.9250e-02, -2.1058e-02, -2.3320e-02,  8.6730e-03,
#         -3.7448e-02, -1.9897e-03,  4.1214e-02, -7.3180e-02,  3.4545e-02,
#          4.8063e-02, -2.9539e-03,  1.2147e-02, -4.1696e-02,  3.4021e-03],
#        grad_fn=<SelectBackward0>)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
points = points.to(device)

out = model(points)
